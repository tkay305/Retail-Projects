# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*

# %% [markdown]
# # Introduction to Problem Space
#
# As a data analyst at Pens and Printers, I have been tasked with analyzing sales strategy methods, following the launch of a new stationary line. I'm required to cover the following touch points:
#
# ## Written Report
# Your written report should include written text summaries and graphics of the following:
#
# ● Data validation:
# - Describe validation and cleaning steps for every column in the data
#
# ● Exploratory Analysis to answer the customer questions ensuring you include:
# - Two different types of graphic showing single variables only
# - At least one graphic showing two or more variables
# - Description of your findings
#
# ● Definition of a metric for the business to monitor
# - How should the business monitor what they want to achieve?
# - Estimate the initial value(s) for the metric based on the current data?
#
# ● Final summary including recommendations that the business should undertake
#
#
# ## Presentation
# You will give an overview presentation to the sales rep who requested the work. The
# presentation should include:
#
# ● An overview of the project and business goals
#
# ● A summary of the work you undertook and how this addresses the problem
#
# ● Your key findings including the metric to monitor and current estimation
#
# ● Your recommendations to the business

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation

# %%
import pandas as pd
df= pd.read_csv('product_sales.csv')
df.head()
# Out:
#    week  sales_method  ... nb_site_visits      state
# 0     2         Email  ...             24    Arizona
# 1     6  Email + Call  ...             28     Kansas
# 2     5          Call  ...             26  Wisconsin
# 3     4         Email  ...             25    Indiana
# 4     3         Email  ...             28   Illinois
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   week               15000 non-null  int64
#  1   sales_method       15000 non-null  object
#  2   customer_id        15000 non-null  object
#  3   nb_sold            15000 non-null  int64
#  4   revenue            13926 non-null  float64
#  5   years_as_customer  15000 non-null  int64
#  6   nb_site_visits     15000 non-null  int64
#  7   state              15000 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 937.6+ KB

# %%
df["week"].agg(["min", "max"])
# Out:
# min    1
# max    6
# Name: week, dtype: int64

# %%
df["sales_method"].value_counts()
replace_values = {'em + call' : 'Email + Call', 'email' : 'Email' }   

df["sales_method"]= df["sales_method"].replace(replace_values)
df["sales_method"].value_counts()
# Out:
# Email           7466
# Call            4962
# Email + Call    2572
# Name: sales_method, dtype: int64

# %%
df["customer_id"].nunique()
# Out:
# 15000

# %%
df[df["revenue"].isnull()]
# Out:
#        week  sales_method  ... nb_site_visits         state
# 0         2         Email  ...             24       Arizona
# 3         4         Email  ...             25       Indiana
# 16        2         Email  ...             30  Pennsylvania
# 17        6  Email + Call  ...             24     Wisconsin
# 28        5         Email  ...             32       Florida
# ...     ...           ...  ...            ...           ...
# 14951     5          Call  ...             25      Virginia
# 14957     1          Call  ...             23      Illinois
# 14970     4  Email + Call  ...             25    Washington
# 14992     5  Email + Call  ...             34      New York
# 14999     5  Email + Call  ...             25      Illinois
#
# [1074 rows x 8 columns]

# %%
df["years_as_customer"].agg(["min", "max"])
df.drop(df[df["years_as_customer"] > 39 ].index, inplace=True)

# %%
df["nb_site_visits"].agg(["min", "max"])
# Out:
# min    12
# max    41
# Name: nb_site_visits, dtype: int64

# %%
df["state"].value_counts()
df["state"].unique()
# Out:
# array(['Arizona', 'Kansas', 'Wisconsin', 'Indiana', 'Illinois',
#        'Mississippi', 'Georgia', 'Oklahoma', 'Massachusetts', 'Missouri',
#        'Texas', 'New York', 'Maryland', 'California', 'Tennessee',
#        'Pennsylvania', 'North Dakota', 'Florida', 'Michigan',
#        'North Carolina', 'Hawaii', 'Colorado', 'Louisiana', 'Virginia',
#        'New Mexico', 'Arkansas', 'Alaska', 'Oregon', 'New Hampshire',
#        'Ohio', 'New Jersey', 'Connecticut', 'Iowa', 'Montana',
#        'Washington', 'Kentucky', 'Alabama', 'Nebraska', 'South Carolina',
#        'Minnesota', 'South Dakota', 'Delaware', 'Maine', 'Utah',
#        'West Virginia', 'Vermont', 'Rhode Island', 'Nevada', 'Idaho',
#        'Wyoming'], dtype=object)

# %%
df.shape[0]
# Out:
# 14998

# %% [markdown]
# # Data Validation
#
# The product sales data frame has **8 columns and 15,000 rows**. After data validation and cleaning, we have **13924 rows of complete, reliable data to work with**. The validation for each of the columns is as follows:
#
# - Week: The data type and range of values (between 1st and 6th week since start of campaign) are as expected. There are no missing values and no data cleaning is necessary.
#
# - Sales Method: The data type for a categorical variable is as expected. However, the categories "Email + Call" and "Email" had variations in text imputation that have since been corrected. There are no missing values.
#
# - Customer ID: As expected, there is a unique identifier for each customer. There are no missing values.
#
# - Nb sold: The data type for the column representing the number of new products sold is numeric as expected. There are no missing values.
#
# - Revenue: The data type representing revenue earned is float type, as expected. There are 1,074 null values. There is no observable pattern between the revenue earned/number of products sold or where they are delivered. For this reason, filling in missing values will not be attempted and rows have been dropped.
#
# - Years as customer: Since Pens and Printers was founded in 1984, we expect the maximum value for this column to be 39. We have two rows where the value is outside of range, and these values have been dropped.
#
# - Nb site visits: The data type for the column representing the number of site visits is numeric as expected. There are no missing values.
#
#
# - State: The data type for a categorical variable is as expected. There are no variations in text imputation by state and there are no missing values.

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## What is the distribution of New Product Sales?

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

sns.histplot(data =df, x= "nb_sold", discrete=True, binwidth=1 ).set(title = 'Distribution of New Product Sales')
plt.xlabel('Number of New Products Sold')
plt.savefig('customers_by_sales_method.png')
plt.show()

# %% [markdown]
# ## What is the distribution of Customers by Sales Method?
#
# - Of the 13,924 customers analysed, half were contacted by Email, under a third by Call and the remaining sixth were contacted by both Email and Call.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns


customer_by_method = df.groupby(by="sales_method").agg({'customer_id':'count'}).reset_index()
pal = sns.color_palette("colorblind", customer_by_method["sales_method"].nunique())
rank = customer_by_method["sales_method"].argsort()
sns.barplot( y= "customer_id", x= "sales_method", palette=np.array(pal[::-1])[rank],data= customer_by_method).set(title = 'Customers by Sales Method')
plt.xlabel('Sales Method')
plt.ylabel('Number of Customers')
plt.savefig('customers_by_sales_method.png')
plt.show()

# were an equal number of initial customers approached? from data frame, all we can see is there is a higher number of customers that purchased new products when contacted by email. What about revenue per customer by type?

# %% [markdown]
# ## What is the distribution of Revenue?
#
# 51% of all revenue from new product sales were earned from customers contacted by Email, 31% of revenue was from customers contacted by Email and Call. The customers contacted by phone Call contributed 17% of new product sales. Despite having a smaller customer base, the group that was contacted by Email and Call earned almost double the revenue of the group that was contacted by only calls.
# There is room to earn higher revenue by contacting more customers by Email + Call rather than through Call only.

# %%
sns.boxplot(data =df, x= "revenue" ).set(title = 'Revenue Earned Distribution')
plt.xlabel('Revenue')
plt.savefig('customers_by_sales_method.png')
plt.show()

# %%
revenue_by_method = df.groupby(by="sales_method").agg({'revenue':'sum'}).reset_index()
sns.barplot( y= "revenue", x= "sales_method", palette=np.array(pal[::-1])[rank], data= revenue_by_method).set(title = 'Revenue by Sales Method')
plt.xlabel('Sales Method')
plt.ylabel('Revenue Earned ($)')
plt.gca().yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.savefig('revenue_by_sales_method.png')
plt.show()

# %% [markdown]
# ## What is the distribution of Revenue?
#
# ### Revenue by Sales Method
# - Email + Call method has the highest revenue per customer, with a median revenue of just under $185 per customer. Median revenue per customer for customers contacted by calls is nearly  4 times lower than this.
# ### Revenue by State
# - The top 10 states account for 54% of new product sales revenues, while the bottom 20% account for about 10% of revenue. There is room to earn more revenue in the lower performing states.
#
# - Revenue and sales per customer appear to have a consistent range across states, it would be helpful to investigate whether reach out efforts at state-level consisted of the same sample size. It is Important to have data on contacted vs responses to analyse "success rate" across different dimensions.

# %%
# distribution of revenue earned by sales method

sns.boxplot(x="revenue", y="sales_method", data=df).set(title= 'Distribution of Revenue earned per Customer')
plt.ylabel('Sales Method')
plt.xlabel('Revenue Earned ($)')
plt.gca().xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.savefig('revenue_by_method.png')
plt.show()

# %%
revenue_by_method["perc_revenue"] = revenue_by_method["revenue"]/revenue_by_method["revenue"].sum()

revenue_by_method
# Out:
#    sales_method    revenue  perc_revenue
# 0          Call  227513.02      0.173941
# 1         Email  672220.61      0.513934
# 2  Email + Call  408256.69      0.312125

# %%
revenue_by_state = df.groupby(by="state").agg({'revenue':'sum','customer_id':'count','years_as_customer':'median'}).reset_index().sort_values(by='customer_id',ascending=False)
revenue_by_state["perc_total_customers"] = revenue_by_state["customer_id"]/revenue_by_state["customer_id"].sum()
revenue_by_state["perc_total_revenue"] = revenue_by_state["revenue"]/revenue_by_state["revenue"].sum()
revenue_by_state = revenue_by_state.sort_values(by="revenue", ascending=False).head(10)
pal_2 = sns.color_palette("colorblind", revenue_by_state["perc_total_revenue"].nunique())
rank_2 = revenue_by_state["perc_total_revenue"].argsort()
sns.barplot( x= "perc_total_revenue", y= "state", palette=np.array(pal_2[::-1])[rank_2], data= revenue_by_state).set(title = 'Percentage of Total Revenue by State - Top 10 States')
plt.xlabel('Percentage of Total Revenue')
plt.ylabel('State')
plt.show()

# %%
customer_by_state = df.groupby(by="state").agg({'revenue':'sum','customer_id':'count','years_as_customer':'median'}).reset_index().sort_values(by='customer_id',ascending=False)
customer_by_state["perc_total_customers"] = customer_by_state["customer_id"]/customer_by_state["customer_id"].sum()
customer_by_state["perc_total_revenue"] = customer_by_state["revenue"]/customer_by_state["revenue"].sum()
customer_by_state = customer_by_state.sort_values(by="customer_id", ascending=False).head(10)
pal_4 = sns.color_palette("colorblind", customer_by_state["perc_total_customers"].nunique())
rank_4 = customer_by_state["perc_total_customers"].argsort()
sns.barplot( x= "perc_total_customers", y= "state",palette=np.array(pal_4[::-1])[rank_4], data= customer_by_state).set(title = 'Percentage of Total Customers by State - Top 10 States')
plt.xlabel('Percentage of Total Customers')
plt.ylabel('State')
plt.savefig('customer_by_state.png')
plt.show()

# %%
sales_method_analysis = df.groupby(by=["sales_method" ]).agg({'revenue':'sum', 'customer_id':'count'}).reset_index()

sales_method_analysis["revenue_per_customer"] = sales_method_analysis["revenue"]/sales_method_analysis["customer_id"]

sns.barplot(data=sales_method_analysis, x="sales_method",y="revenue_per_customer",palette=np.array(pal[::-1])[rank])
plt.xlabel('Sales Method')
plt.ylabel('Revenue per Customer ($)')
plt.gca().yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.show()

# %% [markdown]
# ## Revenue over Time by Sales Method
#
# ### Email campaign structure:
# _Week 1: First email sent out_
# _Week 4: Second email sent out_
#
# - The first week of the Email campaign earned the highest revenue over the six week period, across all sales methods. The two weeks following, revenue declined, down to half of week 1's earnings by the third week.
# - In week 4, when second emails were sent out, there was a slight increase in revenue, before it declined again in weeks 5 and 6.
#
# ### Call campaign structure:
# _One 30 minute call (no follow up or call to action recorded) in week 1_
#
# - The call method has the lowest revenue earned over time across all methods, though revenue earnings peak in weeks 4 and 5.
#
# ### Call + Email campaign structure
# _Email in week 1, 10 minute follow up call in week 2_
#
# - For this method, we see revenue follow an increasing pattern from weeks 1 to 5, and a slight decline in revenues earned in the final week.
#
#  Given that the Call + Email group **had a third of the customers seen in the Email only group, and a higher revenue earned per customer**, it appears that the Email + Call method has the highest revenue earning potential if exploited.

# %%
revenue_by_method_week = df.groupby(by=["sales_method" , "week"]).agg({'revenue':'sum'}).reset_index()
revenue_by_method_week
sns.barplot( y= "revenue", x= "week", hue= "sales_method", data= revenue_by_method_week).set(title = 'Revenue earned per week')
plt.legend(title="Sales Method")
plt.xlabel('Week of Campaign')
plt.ylabel('Revenue Earned ($)')
plt.gca().yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.savefig('revenue_per_week')
plt.show()

# %% [markdown]
# # Business Metric Recommendations
#
# The goals of the sales team is to have insights into approaches that will increase new product sales. We can measure this by tracking revenue earned against a specific dimension.
#
# A good way to track whether sales are effective is analysing the areas with the most potential, namely:
#
# - **Customers by State** : The data shows that currently, new product sales are concentrated in 10 major states. Across the dimensions of years as customer, revenue per customer and sales units - there appears to be no major differences between the different states. The top performing states have the highest number of customers and in turn the highest revenue.
#
# - By tracking the number of customers that purchased new products in each state, we would have visibility into the increase in product reach at state-level. Currently, the bottom 20 states could expand customer numbers to reach at least 250.

# %%
avg_revenue_by_state = df.groupby(by="state").agg({'customer_id':'count'}).reset_index().sort_values(by='customer_id',ascending=False).head(20)

pal_3 = sns.color_palette("colorblind", avg_revenue_by_state["customer_id"].nunique())
rank_3 = avg_revenue_by_state["customer_id"].argsort()
sns.barplot( x= "customer_id", y= "state", palette=np.array(pal_3[::-1])[rank_3], data= avg_revenue_by_state).set(title = 'Number new product Customers - Top 20 States')
plt.xlabel('Number of Customers - new products only')
plt.ylabel('State')
plt.gca().xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.show()

# %%
bottom_customers_by_state = df.groupby(by="state").agg({'customer_id':'count'}).reset_index().sort_values(by='customer_id',ascending=False).tail(20)

pal_4 = sns.color_palette("colorblind", bottom_customers_by_state["customer_id"].nunique())
rank_4 = bottom_customers_by_state["customer_id"].argsort()
sns.barplot( x= "customer_id", y= "state", palette=np.array(pal_3[::-1])[rank_3], data= bottom_customers_by_state).set(title = 'Number new product Customers - Bottom 20 States')
plt.xlabel('Number of Customers - new products only')
plt.ylabel('State')
plt.gca().xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.show()

# %% [markdown]
# # Final Summary and Recommendations
#
# - If we could obtain data about revenue from missing rows, we could have a more accurate representation of revenue and revenue per customer.
#
# - Revenue per customer and Sales per customer appear to have a consistent range across states, it would be helpful to investigate whether reach out efforts at state-level consisted of the same sample size. It is important to have data on all the customers contacted compared against actual sales completed to analyse the conversion rate from out reach to sales across different dimensions.
#
# - Given that the Call + Email group **had a third of the customers seen in the Email only group, and a higher revenue earned per customer**, it appears that the Email + Call method has the highest revenue earning potential if exploited.

# %% [markdown]
# # Pens and pencils Presenataion: Insight into new product sales

# %% [markdown]
# ## Analysis Overview
# - The sales team has run a campaign to gain insight into 3 reach-out methods on new product line
# - We have six weeks worth of sales based data tracked at customer level
# - We would like to answer the question: What patterns from the reach-out data can we use to improve sales performance?

# %% [markdown]
# ## Summary of process to address problem
#
# - Understanding that data contains completed sales for customers that were approached, which reach-out method they were approached by, sales made and customer personal details
#
# - Grouped customers and revenue by reach-out method to understand how they were distributed
#
# - Grouped customers and revenue by state to look for patterns in purchases
#
# - Looked at distribution of revenue earned per customer by reach-out method

# %% [markdown]
# ## Key findings and choice of metric
#
# ### Customers
#
# - Customers that purchased new products are distributed in the ratio 3:2:1 for Email: Call: Email + Call
# - The distribution of customers by state is concentrated in a few states, and in turn revenue earned from new product sales is concentrated in a few states.
#
# ![customer distribution](customers_by_sales_method.png)
#
# ### Revenue
# - Revenue from new product sales is distributed in the ratio 3:1.8:1 for Email: Call + Email: Call. Despite the customers in the Call + Email group being a third of the Email group, and half of the Call group, they earned 1.8 times more revenue than the Call group.
#
# ![revenue method](revenue_by_sales_method.png)
#
# - Email + Call method therefore has the highest revenue per customer, with a median revenue of just under $200 per customer. Median revenue per customer for customers contacted by calls is about 4 times lower than this.
#
# ![revenue method](revenue_by_method.png)
#
# ### State
#
# - The distribution of customers and therefore revenue is concentrated amongst a select few states : the top ten states have 54% of total customers and revenue, while the bottom 20 states have approximately only 10%. Closing the gap between states in customers and revenue could be key to improving new product sales performance.
#
# ![customer state](customer_by_state.png)
# ### Campaign Revenue over Time
#
# ![revenue_per_week](revenue_per_week.png)
# ### Metric of choice
#
# - **Customers by State** : The data shows that currently, new product sales are concentrated in 10 major states. Across the dimensions of years as customer, revenue per customer and sales units - there appears to be no major differences between the different states. The top performing states have the highest number of customers and in turn the highest revenue.
#
# - By tracking the number of customers that purchased new products in each state, we would have visibility into the increase in product reach at state-level. Currently, the bottom 20 states could expand customer numbers to reach at least 250.

# %% [markdown]
# # Final Summary and Recommendations
#
# - If we could obtain data about revenue from missing rows, we could have a more accurate representation of revenue and revenue per customer.
#
# - Revenue per customer and Sales per customer appear to have a consistent range across states, it would be helpful to investigate whether reach out efforts at state-level consisted of the same sample size. It is important to have data on all the customers contacted compared against actual sales completed to analyse the conversion rate from out reach to sales across different dimensions.
#
# - Given that the Call + Email group **had a third of the customers seen in the Email only group, and a higher revenue earned per customer**, it appears that the Email + Call method has the highest revenue earning potential if exploited.
